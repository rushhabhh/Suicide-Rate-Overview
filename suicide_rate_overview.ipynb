# %%
import pandas as pd
import numpy as np


import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv('/Users/rush/Documents/Documents - Rushabh’s MacBook Air/Data/Suicide Rate Overview/suicide_overview.csv')

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years         21.0      312900
# 1  Albania  1987    male  35-54 years         16.0      308000
# 2  Albania  1987  female  15-24 years         14.0      289700
# 3  Albania  1987    male    75+ years          1.0       21800
# 4  Albania  1987    male  25-34 years          9.0      274300
#
#    suicides/100k pop country-year  HDI for year gdp_for_year($)   \
# 0               6.71  Albania1987           NaN   2,15,66,24,900
# 1               5.19  Albania1987           NaN   2,15,66,24,900
# 2               4.83  Albania1987           NaN   2,15,66,24,900
# 3               4.59  Albania1987           NaN   2,15,66,24,900
# 4               3.28  Albania1987           NaN   2,15,66,24,900
#
#    gdp_per_capita($)       generation
# 0              796.0     Generation X
# 1              796.0           Silent
# 2              796.0     Generation X
# ...

# %%
df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year', 'gdp_for_year($) ',
#        'gdp_per_capita($)', 'generation'],
#       dtype='object')

# %%
df.rename(columns={'gdp_for_year($) ': 'gdp_for_year'}, inplace=True)
df.rename(columns={'gdp_per_capita($)': 'gdp_per_capita'}, inplace=True)
df.rename(columns={'suicides/100k pop': 'suicides/100k'}, inplace=True)
df.rename(columns={'HDI for year': 'hdi_for_year'}, inplace=True)
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  suicides/100k  \
# 0  Albania  1987    male  15-24 years         21.0      312900           6.71
# 1  Albania  1987    male  35-54 years         16.0      308000           5.19
# 2  Albania  1987  female  15-24 years         14.0      289700           4.83
# 3  Albania  1987    male    75+ years          1.0       21800           4.59
# 4  Albania  1987    male  25-34 years          9.0      274300           3.28
#
#   country-year  hdi_for_year    gdp_for_year  gdp_per_capita       generation
# 0  Albania1987           NaN  2,15,66,24,900           796.0     Generation X
# 1  Albania1987           NaN  2,15,66,24,900           796.0           Silent
# 2  Albania1987           NaN  2,15,66,24,900           796.0     Generation X
# 3  Albania1987           NaN  2,15,66,24,900           796.0  G.I. Generation
# 4  Albania1987           NaN  2,15,66,24,900           796.0          Boomers

# %%
df.dtypes
# Out:
# country            object
# year                int64
# sex                object
# age                object
# suicides_no       float64
# population          int64
# suicides/100k     float64
# country-year       object
# hdi_for_year      float64
# gdp_for_year       object
# gdp_per_capita    float64
# generation         object
# dtype: object

# %%
df['country'] = df['country'].astype('category')
df['sex'] = df['sex'].astype('category')
df['age'] = df['age'].astype('category')
df['country-year'] = df['country-year'].astype('category')
df['generation'] = df['generation'].astype('category')

df.dtypes
# Out:
# country           category
# year                 int64
# sex               category
# age               category
# suicides_no        float64
# population           int64
# suicides/100k      float64
# country-year      category
# hdi_for_year       float64
# gdp_for_year        object
# gdp_per_capita     float64
# generation        category
# dtype: object

# %%
df.drop(columns=['country-year'], inplace=True)
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  suicides/100k  \
# 0  Albania  1987    male  15-24 years         21.0      312900           6.71
# 1  Albania  1987    male  35-54 years         16.0      308000           5.19
# 2  Albania  1987  female  15-24 years         14.0      289700           4.83
# 3  Albania  1987    male    75+ years          1.0       21800           4.59
# 4  Albania  1987    male  25-34 years          9.0      274300           3.28
#
#    hdi_for_year    gdp_for_year  gdp_per_capita       generation
# 0           NaN  2,15,66,24,900           796.0     Generation X
# 1           NaN  2,15,66,24,900           796.0           Silent
# 2           NaN  2,15,66,24,900           796.0     Generation X
# 3           NaN  2,15,66,24,900           796.0  G.I. Generation
# 4           NaN  2,15,66,24,900           796.0          Boomers

# %%
df['country'].unique()
# Out:
# ['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', ..., 'Peru', 'Republic of Moldova', 'Saint Vincent and the Grenadines', 'Tajikistan', 'United States of America']
# Length: 114
# Categories (114, object): ['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', ..., 'United States', 'United States of America', 'Uruguay', 'Uzbekistan']

# %%
df['country'] = df['country'].replace('United States of America', 'United States')
df['country'] = df['country'].replace('Russian Federation', 'Russia')

df['country'].unique()
# Out:
# ['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', ..., 'North Macedonia', 'Peru', 'Republic of Moldova', 'Saint Vincent and the Grenadines', 'Tajikistan']
# Length: 113
# Categories (113, object): ['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', ..., 'United Kingdom', 'United States', 'Uruguay', 'Uzbekistan']

# %%
df['generation'].unique()
# Out:
# ['Generation X', 'Silent', 'G.I. Generation', 'Boomers', 'Millenials', 'Generation Z']
# Categories (6, object): ['Boomers', 'G.I. Generation', 'Generation X', 'Generation Z', 'Millenials', 'Silent']

# %%
df['generation'] = df['generation'].replace('Millenials', 'Generation Y')
df['generation'].unique()
# Out:
# ['Generation X', 'Silent', 'G.I. Generation', 'Boomers', 'Generation Y', 'Generation Z']
# Categories (6, object): ['Boomers', 'G.I. Generation', 'Generation X', 'Generation Z', 'Generation Y', 'Silent']

# %%
df.isnull().sum().sum()
# Out:
# 20656

# %%
df.isnull().sum()
# Out:
# country               0
# year                  0
# sex                   0
# age                   0
# suicides_no        1200
# population            0
# suicides/100k         0
# hdi_for_year      19456
# gdp_for_year          0
# gdp_per_capita        0
# generation            0
# dtype: int64

# %%
data_with_null_suicides_no = df[df['suicides_no'].isnull()]
data_with_null_suicides_no
# Out:
#                    country  year     sex         age  suicides_no  population  \
# 27820  Antigua and Barbuda  2020    male  5-14 years          NaN       92664
# 27821            Argentina  2020    male  5-14 years          NaN    45376763
# 27822              Armenia  2020    male  5-14 years          NaN     2805608
# 27825              Belarus  2020    male  5-14 years          NaN     9379952
# 27826              Belgium  2020    male  5-14 years          NaN    11538604
# ...                    ...   ...     ...         ...          ...         ...
# 31668               Turkey  2018  female   75+ years          NaN    82809304
# 31679              Belarus  2017  female   75+ years          NaN     9458989
# 31707              Ireland  2017  female   75+ years          NaN     4807388
# 31716              Lebanon  2017  female   75+ years          NaN     6109252
# 31750               Turkey  2017  female   75+ years          NaN    82089826
#
# ...

# %%
df['suicides_no'].fillna(0, inplace=True)
df['hdi_for_year'].fillna(0, inplace=True)
df.isnull().sum()
# Out:
# country           0
# year              0
# sex               0
# age               0
# suicides_no       0
# population        0
# suicides/100k     0
# hdi_for_year      0
# gdp_for_year      0
# gdp_per_capita    0
# generation        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31756 entries, 0 to 31755
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         31756 non-null  category
#  1   year            31756 non-null  int64
#  2   sex             31756 non-null  category
#  3   age             31756 non-null  category
#  4   suicides_no     31756 non-null  float64
#  5   population      31756 non-null  int64
#  6   suicides/100k   31756 non-null  float64
#  7   hdi_for_year    31756 non-null  float64
#  8   gdp_for_year    31756 non-null  object
#  9   gdp_per_capita  31756 non-null  float64
#  10  generation      31756 non-null  category
# dtypes: category(4), float64(4), int64(2), object(1)
# memory usage: 1.8+ MB

# %%
df.describe()
# Out:
#                year   suicides_no    population  suicides/100k  hdi_for_year  \
# count  31756.000000  31756.000000  3.175600e+04   31756.000000  31756.000000
# mean    2003.395390    228.175305  7.217454e+06      11.716668      0.307409
# std        9.760604    852.598398  5.799323e+07      21.590926      0.391363
# min     1985.000000      0.000000  2.780000e+02       0.000000      0.000000
# 25%     1996.000000      2.000000  1.288210e+05       0.370000      0.000000
# 50%     2004.000000     22.000000  5.468325e+05       4.285000      0.000000
# 75%     2011.000000    123.000000  2.908763e+06      14.560000      0.758440
# max     2020.000000  22338.000000  1.411100e+09     515.092734      0.975114
#
#        gdp_per_capita
# count    31756.000000
# mean     17588.954606
# std      19464.861140
# min        251.000000
# 25%       3765.000000
# 50%      10062.000000
# 75%      25622.000000
# max     126352.000000

# %%
df.nunique()
# Out:
# country             113
# year                 36
# sex                   2
# age                   6
# suicides_no        2097
# population        25891
# suicides/100k      7466
# hdi_for_year        922
# gdp_for_year       2631
# gdp_per_capita     2561
# generation            6
# dtype: int64

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  suicides/100k  \
# 0  Albania  1987    male  15-24 years         21.0      312900           6.71
# 1  Albania  1987    male  35-54 years         16.0      308000           5.19
# 2  Albania  1987  female  15-24 years         14.0      289700           4.83
# 3  Albania  1987    male    75+ years          1.0       21800           4.59
# 4  Albania  1987    male  25-34 years          9.0      274300           3.28
#
#    hdi_for_year    gdp_for_year  gdp_per_capita       generation
# 0           0.0  2,15,66,24,900           796.0     Generation X
# 1           0.0  2,15,66,24,900           796.0           Silent
# 2           0.0  2,15,66,24,900           796.0     Generation X
# 3           0.0  2,15,66,24,900           796.0  G.I. Generation
# 4           0.0  2,15,66,24,900           796.0          Boomers

# %%
df.tail()
# Out:
#               country  year     sex        age  suicides_no  population  \
# 31751         Ukraine  2017  female  75+ years        256.0    44831135
# 31752  United Kingdom  2017  female  75+ years        104.0    66058859
# 31753   United States  2017  female  75+ years        501.0   325122128
# 31754         Uruguay  2017  female  75+ years         14.0     3422200
# 31755      Uzbekistan  2017  female  75+ years          3.0    32388600
#
#        suicides/100k  hdi_for_year gdp_for_year  gdp_per_capita  \
# 31751       0.571032      0.785458     1.12E+11     2638.326055
# 31752       0.157435      0.914735     2.70E+12    40857.755580
# 31753       0.154096      0.918620     1.95E+13    60109.655730
# 31754       0.409094      0.816745  64233966861    18690.893840
# 31755       0.009263      0.691258  62081323299     1916.764642
#
#             generation
# 31751  G.I. Generation
# 31752  G.I. Generation
# 31753  G.I. Generation
# 31754  G.I. Generation
# 31755  G.I. Generation

# %%
suicides_by_country = df.groupby('country')['suicides_no'].sum()
print(suicides_by_country)
# Out:
# country
# Albania                    1970.0
# Antigua and Barbuda          11.0
# Argentina                 91931.0
# Armenia                    2057.0
# Aruba                       101.0
#                           ...
# United Arab Emirates        622.0
# United Kingdom           152238.0
# United States           1095226.0
# Uruguay                   15258.0
# Uzbekistan                41816.0
# Name: suicides_no, Length: 113, dtype: float64

# %%
min_year = df['year'].min()
max_year = df['year'].max()

print("Minimum Year:", min_year)
print("Maximum Year:", max_year)
# Out:
# Minimum Year: 1985
# Maximum Year: 2020

# %%
df.to_csv('/Users/rush/Documents/Documents - Rushabh’s MacBook Air/Data/Suicide Rate Overview/suicide_overview_cleaned.csv')
